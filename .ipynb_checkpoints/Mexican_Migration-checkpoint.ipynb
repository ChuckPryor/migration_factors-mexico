# %%
import pandas as pd
df = pd.read_csv('united-states-gdp-growth-rate.csv', skiprows = 16, sep=",")
df
# Out:
#           date   GDP Growth (%)   Annual Change
# 0   1961-12-31           2.3000             NaN NaN
# 1   1962-12-31           6.1000            3.80 NaN
# 2   1963-12-31           4.4000           -1.70 NaN
# 3   1964-12-31           5.8000            1.40 NaN
# 4   1965-12-31           6.4000            0.60 NaN
# 5   1966-12-31           6.5000            0.10 NaN
# 6   1967-12-31           2.5000           -4.00 NaN
# 7   1968-12-31           4.8000            2.30 NaN
# 8   1969-12-31           3.1000           -1.70 NaN
# 9   1970-12-31          -0.3228           -3.42 NaN
# 10  1971-12-31           3.2934            3.62 NaN
# 11  1972-12-31           5.2589            1.97 NaN
# 12  1973-12-31           5.6457            0.39 NaN
# 13  1974-12-31          -0.5405           -6.19 NaN
# 14  1975-12-31          -0.2055            0.34 NaN
# 15  1976-12-31           5.3881            5.59 NaN
# 16  1977-12-31           4.6242           -0.76 NaN
# ...

# %%
df.head(35)
# Out:
#                             Macrotrends Data Download
# 0                      U.S. GDP Growth Rate 1961-2021
# 1   DISCLAIMER AND TERMS OF USE: HISTORICAL DATA I...
# 2   FOR INFORMATIONAL PURPOSES - NOT FOR TRADING P...
# 3   NEITHER MACROTRENDS LLC NOR ANY OF OUR INFORMA...
# 4   FOR ANY DAMAGES RELATING TO YOUR USE OF THE DA...
# 5   ATTRIBUTION: Proper attribution requires clear...
# 6   A "dofollow" backlink to the originating page ...
# 7                                              , , ,
# 8               date, GDP Growth (%), Annual Change,
# 9                                      1961-12-31,2.3
# 10                                 1962-12-31,6.1,3.8
# 11                                1963-12-31,4.4,-1.7
# 12                                 1964-12-31,5.8,1.4
# 13                                 1965-12-31,6.4,0.6
# 14                                 1966-12-31,6.5,0.1
# 15                                  1967-12-31,2.5,-4
# ...

# %%
df1 = df.drop(df.index[[0,7]])

# %%
df1
# Out:
#                             Macrotrends Data Download
# 1   DISCLAIMER AND TERMS OF USE: HISTORICAL DATA I...
# 2   FOR INFORMATIONAL PURPOSES - NOT FOR TRADING P...
# 3   NEITHER MACROTRENDS LLC NOR ANY OF OUR INFORMA...
# 4   FOR ANY DAMAGES RELATING TO YOUR USE OF THE DA...
# 5   ATTRIBUTION: Proper attribution requires clear...
# ..                                                ...
# 63                              2015-12-31,2.908,0.38
# 64                            2016-12-31,1.6378,-1.27
# 65                             2017-12-31,2.3698,0.73
# 66                             2018-12-31,2.9273,0.56
# 67                            2019-12-31,2.1612,-0.77
#
# [66 rows x 1 columns]
